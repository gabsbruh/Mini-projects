# %% [markdown]
# # Introduction
#
# Comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.sample(5)
# Out:
#                                App   Category  Rating  Reviews  Size_MBs  \
# 502                      DZ Puzzle     FAMILY     NaN       14     47.00
# 1264                      EG India  LIFESTYLE    5.00        3      4.00
# 8724                  ABCmouse.com     FAMILY    4.30    50887     91.00
# 5833            BF Combat: Genesis       GAME    4.00     3322     82.00
# 3210  Elemental Galaxy Dx - Match3     FAMILY    4.00      127     14.00
#
#        Installs  Type  Price Content_Rating               Genres  \
# 502          10  Paid  $0.99       Everyone               Puzzle
# 1264        100  Free      0       Everyone            Lifestyle
# 8724  5,000,000  Free      0       Everyone  Education;Education
# 5833    100,000  Free      0     Mature 17+               Action
# 3210     10,000  Free      0       Everyone               Puzzle
#
#         Last_Updated   Android_Ver
# 502   April 22, 2017    2.3 and up
# 1264   July 29, 2018  4.0.3 and up
# 8724    July 3, 2018    4.4 and up
# 5833   March 2, 2017    2.3 and up
# 3210  March 11, 2014    2.2 and up

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %% [markdown]
# ### Drop Unused Columns

# %%
df_apps.drop(['Last_Updated', "Android_Ver"], axis=1, inplace=True)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
len(df_apps)
# Out:
# 10841

# %%
df_apps_clean = df_apps.dropna(subset=["Rating"])

# %%
len(df_apps_clean)
# Out:
# 9367

# %% [markdown]
# ### Remove Duplicates

# %%
df_apps_clean.duplicated().sum()
# Out:
# 476

# %%
df_apps_clean[df_apps_clean["App"] == "Instagram"].duplicated().sum()
# Out:
# 1

# %%
df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"], inplace=True)
# Out:
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\2986174200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"], inplace=True)

# %%
len(df_apps_clean)
# Out:
# 8199

# %% [markdown]
# # Highest Rated Apps

# %%
ratings = df_apps_clean.sort_values("Rating", ascending=False)
ratings.head(10)
# Out:
#                                                    App      Category  Rating  \
# 21                                 KBA-EZ Health Guide       MEDICAL    5.00
# 1230                                      Sway Medical       MEDICAL    5.00
# 1227                                 AJ Men's Grooming     LIFESTYLE    5.00
# 1224                                    FK Dedinje BGD        SPORTS    5.00
# 1223                                   CB VIDEO VISION   PHOTOGRAPHY    5.00
# 1222                        Beacon Baptist Jupiter, FL     LIFESTYLE    5.00
# 1214                                    BV Mobile Apps  PRODUCTIVITY    5.00
# 2680                               Florida Wildflowers        FAMILY    5.00
# 1206                                      ADS-B Driver         TOOLS    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News        COMICS    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating        Genres
# 21          4     25.00        1  Free      0       Everyone       Medical
# 1230        3     22.00      100  Free      0       Everyone       Medical
# 1227        2     22.00      100  Free      0       Everyone     Lifestyle
# 1224       36      2.60      100  Free      0       Everyone        Sports
# 1223       13      2.60      100  Free      0       Everyone   Photography
# 1222       14      2.60      100  Free      0       Everyone     Lifestyle
# 1214        3      4.80      100  Free      0       Everyone  Productivity
# 2680        5     69.00    1,000  Free      0       Everyone     Education
# 1206        2      6.30      100  Paid  $1.99       Everyone         Tools
# 2750       34     12.00    5,000  Free      0       Everyone        Comics

# %% [markdown]
# *Not enough reviews*

# %% [markdown]
# # Largest Apps in terms of Size (MBs)

# %%
largest_apps = df_apps_clean.sort_values("Size_MBs", ascending=False)
largest_apps.head(10)
# Out:
#                                                     App            Category  \
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 10687                            Hungry Shark Evolution                GAME
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 9945                                    Ultimate Tennis              SPORTS
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
#
#        Rating  Reviews  Size_MBs     Installs  Type  Price Content_Rating  \
# 9942     4.00   140995    100.00   10,000,000  Free      0       Everyone
# 10687    4.50  6074334    100.00  100,000,000  Free      0           Teen
# 9943     4.00   254518    100.00   10,000,000  Free      0     Mature 17+
# 9944     4.30    65146    100.00   10,000,000  Free      0     Mature 17+
# 3144     3.60      124    100.00        5,000  Free      0       Everyone
# 9945     4.30   183004    100.00   10,000,000  Free      0       Everyone
# 7926     4.50    60449    100.00    1,000,000  Free      0       Everyone
# 7927     4.00    22435    100.00    1,000,000  Free      0           Teen
# 7928     4.40    38419    100.00    1,000,000  Paid  $0.99   Everyone 10+
# 4176     3.60      151    100.00       10,000  Free      0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# 3144         Health & Fitness
# 9945                   Sports
# 7926                  Finance
# 7927                   Action
# 7928                   Action
# 4176                   Racing

# %% [markdown]
# # App with Most Reviews

# %%
reviews = df_apps_clean.sort_values("Reviews", ascending=False)
reviews.head(10)
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10785                                 WhatsApp Messenger  COMMUNICATION
# 10806                                          Instagram         SOCIAL
# 10784           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10650                                     Clash of Clans           GAME
# 10744            Clean Master- Space Cleaner & Antivirus          TOOLS
# 10835                                     Subway Surfers           GAME
# 10828                                            YouTube  VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10584                                       Clash Royale           GAME
#
#        Rating   Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10805    4.10  78158306      5.30  1000000000  Free   0.00           Teen
# 10785    4.40  69119316      3.50  1000000000  Free   0.00       Everyone
# 10806    4.50  66577313      5.30  1000000000  Free   0.00           Teen
# 10784    4.00  56642847      3.50  1000000000  Free   0.00       Everyone
# 10650    4.60  44891723     98.00   100000000  Free   0.00   Everyone 10+
# 10744    4.70  42916526      3.40   500000000  Free   0.00       Everyone
# 10835    4.50  27722264     76.00  1000000000  Free   0.00   Everyone 10+
# 10828    4.30  25655305      4.65  1000000000  Free   0.00           Teen
# 10746    4.70  24900999      3.40   500000000  Free   0.00       Everyone
# 10584    4.60  23133508     97.00   100000000  Free   0.00   Everyone 10+
#
#                         Genres  Revenue_Estimate
# 10805                   Social              0.00
# 10785            Communication              0.00
# 10806                   Social              0.00
# 10784            Communication              0.00
# 10650                 Strategy              0.00
# 10744                    Tools              0.00
# 10835                   Arcade              0.00
# 10828  Video Players & Editors              0.00
# 10746                    Tools              0.00
# 10584                 Strategy              0.00

# %%
head_reviews = reviews.head(50)
head_reviews[head_reviews["Type"] == "Paid"].count()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %% [markdown]
# # Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title='Content Ratings', names=ratings.index, hole=0.4)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# c:\Users\gabso\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:138: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return args["labels"][column]

# %% [markdown]
# # Examine the Number of Installs

# %%
print("Apps with more than BILLION installations: ", df_apps_clean.Installs.value_counts().loc["1,000,000,000"])
print("Number of apps with only 1 installation: ", df_apps_clean.Installs.value_counts().loc["1"])
# Out:
# Apps with more than BILLION installations:  20
# Number of apps with only 1 installation:  3

# %% [markdown]
# # Most Expensive Apps & Calculate Sales Revenue Estimate

# %%
df_apps_clean.Price = df_apps_clean.Price.str.replace("$", "", regex=False)  # usuwasz znaki dolara z tekstu. gdy ustawisz parametr regex na false
# to nie traktuje dolara jako notacji regexowej

df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
most_expensive_apps = df_apps_clean.sort_values("Price", ascending=False)
most_expensive_apps.head(20)
# Out:
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\1093545204.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\1093545204.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 2281       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407                    LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629                I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481         A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 4264         Golfshot Plus: Golf GPS     SPORTS    4.10     3387     25.00
#
#      Installs  Type  Price Content_Rating         Genres
# 3946   10,000  Paid 400.00       Everyone      Lifestyle
# 2461    1,000  Paid 399.99       Everyone        Finance
# 4606   50,000  Paid 399.99       Everyone        Finance
# 3145    5,000  Paid 399.99       Everyone        Finance
# 3554   10,000  Paid 399.99       Everyone      Lifestyle
# 5765  100,000  Paid 399.99       Everyone      Lifestyle
# 1946    1,000  Paid 399.99           Teen        Finance
# 2775    5,000  Paid 399.99       Everyone  Entertainment
# 3221   10,000  Paid 399.99       Everyone  Entertainment
# 3114    5,000  Paid 399.99       Everyone        Finance
# 1331      100  Paid 399.99       Everyone  Entertainment
# 2394    1,000  Paid 399.99       Everyone        Finance
# 3897   10,000  Paid 389.99       Everyone  Entertainment
# 2193    1,000  Paid 379.99       Everyone      Lifestyle
# 3856   10,000  Paid 299.99       Everyone      Lifestyle
# 2281    1,000  Paid  79.99       Everyone        Medical
# 1407      100  Paid  39.99       Everyone        Medical
# 2629    1,000  Paid  37.99       Everyone      Lifestyle
# 2481    1,000  Paid  33.99       Everyone        Medical
# 4264   50,000  Paid  29.99       Everyone         Sports

# %% [markdown]
# ### The most expensive apps sub $250

# %%
expensive_under_250 = most_expensive_apps[most_expensive_apps["Price"] < 250]
expensive_under_250.head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 2207                                           EMT PASS      MEDICAL    3.40
# 2463                                 PTA Content Master      MEDICAL    4.20
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 2293                               Hospitalist Handbook      MEDICAL    4.80
# 526                          USMLE Step 2 CK Flashcards       FAMILY    5.00
# 4470                                  DRAGON QUEST VIII       FAMILY    4.50
# 2119                                         NewTek NDI  PHOTOGRAPHY    3.50
# 2473                            boattheory.ch Full 2018       FAMILY    4.70
# 4090                             I am Rich Premium Plus      FINANCE    4.60
# 1508                                 SkyTest BU/GU Lite     BUSINESS    2.90
# 3778                            The World Ends With You         GAME    4.60
# 2603                         2017 EMRA Antibiotic Guide      MEDICAL    4.40
# 3439                            Trine 2: Complete Story         GAME    3.80
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating        Genres
# 2281       92     32.00    1,000  Paid  79.99       Everyone       Medical
# 1407        6      1.30      100  Paid  39.99       Everyone       Medical
# 2629      134      1.80    1,000  Paid  37.99       Everyone     Lifestyle
# 2481      214     68.00    1,000  Paid  33.99       Everyone       Medical
# 4264     3387     25.00   50,000  Paid  29.99       Everyone        Sports
# 504         1     96.00       10  Paid  29.99     Mature 17+     Education
# 2207       51      2.40    1,000  Paid  29.99       Everyone       Medical
# 2463       64     41.00    1,000  Paid  29.99       Everyone       Medical
# 3241      168     25.00   10,000  Paid  24.99       Everyone       Medical
# 4772     2921     25.00  100,000  Paid  24.99       Everyone       Medical
# 2293       12     18.00    1,000  Paid  19.99       Everyone       Medical
# 526         1     40.00       10  Paid  19.99       Everyone     Education
# 4470     7812     27.00   50,000  Paid  19.99   Everyone 10+  Role Playing
# 2119       77      1.20    1,000  Paid  19.99       Everyone   Photography
# 2473       54     50.00    1,000  Paid  19.40       Everyone     Education
# 4090      459      2.00   10,000  Paid  18.99       Everyone       Finance
# 1508       28     20.00      500  Paid  17.99       Everyone      Business
# 3778     4108     13.00   10,000  Paid  17.99   Everyone 10+        Arcade
# 2603       12      3.80    1,000  Paid  16.99       Everyone       Medical
# 3439      252     11.00   10,000  Paid  16.99           Teen        Action

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
expensive_under_250.Installs = expensive_under_250.Installs.astype('str').str.replace(",", '')
expensive_under_250.Installs = pd.to_numeric(expensive_under_250.Installs)

expensive_under_250["Revenue_Estimate"] = expensive_under_250.Installs.mul(expensive_under_250.Price)
expensive_under_250.sort_values("Revenue_Estimate", ascending=False).head(10)
# Out:
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3828833638.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3828833638.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3828833638.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 App       Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft         FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper           GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas           GAME    4.40   348962     26.00
# 7477            Facetune - For Free    PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock      LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator           GAME    4.60    87766     12.00
# 6082                   Weather Live        WEATHER    4.50    76593      4.75
# 7954                    Bloons TD 5         FAMILY    4.60   190086     94.00
# 6856                        Threema  COMMUNICATION    4.50    51110      3.50
# 6746     Card Wars - Adventure Time         FAMILY    4.30   129603     23.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7477   1000000  Paid   5.99       Everyone                Photography
# 7977   1000000  Paid   5.99       Everyone                  Lifestyle
# 6594   1000000  Paid   4.99       Everyone                     Action
# 6082    500000  Paid   5.99       Everyone                    Weather
# 7954   1000000  Paid   2.99       Everyone                   Strategy
# 6856   1000000  Paid   2.99       Everyone              Communication
# 6746   1000000  Paid   2.99   Everyone 10+    Card;Action & Adventure
#
#       Revenue_Estimate
# 9220     69,900,000.00
# 8825      9,900,000.00
# 7151      6,990,000.00
# 7477      5,990,000.00
# 7977      5,990,000.00
# 6594      4,990,000.00
# 6082      2,995,000.00
# 7954      2,990,000.00
# 6856      2,990,000.00
# 6746      2,990,000.00

# %% [markdown]
# # Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()
top10_category
# Out:
# FAMILY                 1610
# GAME                    910
# TOOLS                   719
# FINANCE                 302
# LIFESTYLE               302
# PRODUCTIVITY            301
# PERSONALIZATION         298
# MEDICAL                 292
# PHOTOGRAPHY             263
# BUSINESS                262
# SPORTS                  260
# COMMUNICATION           257
# HEALTH_AND_FITNESS      243
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       64
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           61
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# Name: Category, dtype: int64

# %%
bar = px.bar(x = top10_category.index[:10],
             y= top10_category.values[:10])
bar.show()

# %% [markdown]
# ### Highest Competition (Number of Apps)

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype('str').str.replace(",", '')
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
most_installed = df_apps_clean.groupby('Category').agg({"Installs": pd.Series.sum})
ten_most_installed = most_installed.sort_values("Installs", ascending=False, inplace=False)[:10]
ten_most_installed = ten_most_installed.sort_values("Installs", ascending=True, inplace=False)[:10]
installed_bar = px.bar(x=ten_most_installed.Installs, y=ten_most_installed.index, orientation='h', title="Most Installed Apps")
installed_bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")
installed_bar.show()
# Out:
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\2243764941.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\2243764941.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Most Popular Categories (Highest Downloads)

# %%
most_installed
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         114233100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1665791655
# BUSINESS               692018120
# COMICS                  44931100
# COMMUNICATION        11039241530
# DATING                 140912410
# EDUCATION              352852000
# ENTERTAINMENT         2113660000
# EVENTS                  15949410
# FAMILY                4437579590
# FINANCE                455312400
# FOOD_AND_DRINK         211677750
# GAME                 13858762717
# HEALTH_AND_FITNESS    1134006220
# HOUSE_AND_HOME          97082000
# LIBRARIES_AND_DEMO      52083000
# LIFESTYLE              503742120
# MAPS_AND_NAVIGATION    503267560
# MEDICAL                 39162676
# NEWS_AND_MAGAZINES    2369110650
# PARENTING               31116110
# PERSONALIZATION       1532352930
# PHOTOGRAPHY           4649143130
# PRODUCTIVITY          5788070180
# SHOPPING              1400331540
# SOCIAL                5487841475
# SPORTS                1096431465
# TOOLS                 8099724500
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# WEATHER                361096500

# %%
installs_merge = pd.concat([top10_category, most_installed], axis=1)

# %%
scatter = px.scatter(data_frame=installs_merge,
                     x='Category',
                     y="Installs",
                     size="Category",
                     hover_name=installs_merge.index,
                     color="Installs",
                     title="Category Concentration")

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
scatter.show()

# %% [markdown]
# # Top Genres

# %%
df_apps_clean.head(10)
# Out:
#                                                  App  Category  Rating  \
# 21                               KBA-EZ Health Guide   MEDICAL    5.00
# 28                                          Ra Ga Ba      GAME    5.00
# 47                                           Mu.F.O.      GAME    5.00
# 82                                  Brick Breaker BR      GAME    5.00
# 99   Anatomy & Physiology Vocabulary Exam Review App   MEDICAL    5.00
# 114                                      FK Atlantas    SPORTS    1.50
# 126                                  Tablet Reminder   MEDICAL    5.00
# 128                                          CQ ESPM  BUSINESS    5.00
# 141                                Clinic Doctor EHr   MEDICAL    5.00
# 151                              EB Cash Collections  BUSINESS    5.00
#
#      Reviews  Size_MBs  Installs  Type  Price Content_Rating    Genres
# 21         4     25.00         1  Free   0.00       Everyone   Medical
# 28         2     20.00         1  Paid   1.49       Everyone    Arcade
# 47         2     16.00         1  Paid   0.99       Everyone    Arcade
# 82         7     19.00         5  Free   0.00       Everyone    Arcade
# 99         1      4.60         5  Free   0.00       Everyone   Medical
# 114        2     26.00         5  Free   0.00       Everyone    Sports
# 126        4      2.50         5  Free   0.00       Everyone   Medical
# 128        2      3.40         5  Free   0.00       Everyone  Business
# 141        2      7.10         5  Free   0.00       Everyone   Medical
# 151        1      4.30         5  Free   0.00       Everyone  Business

# %%
genres_num = df_apps_clean.Genres.str.split(';', expand=True).stack()
genres_counted = genres_num.value_counts()
genres_counted
# Out:
# Tools                      719
# Education                  587
# Entertainment              502
# Action                     304
# Lifestyle                  303
# Finance                    302
# Productivity               301
# Personalization            298
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# Food & Drink                94
# Educational                 93
# Adventure                   78
# Auto & Vehicles             73
# Weather                     72
# Pretend Play                68
# Brain Games                 65
# Libraries & Demo            64
# Art & Design                62
# House & Home                62
# Board                       57
# Comics                      54
# Parenting                   50
# Card                        46
# Events                      45
# Beauty                      42
# Casino                      37
# Music & Video               31
# Creativity                  31
# Trivia                      28
# Word                        22
# Music                       21
# Music & Audio                1
# dtype: int64

# %%
genres_bar = px.bar(x=genres_counted.index[:15],
                    y=genres_counted.values[:15],
                    title='Top Genres',
                    hover_name=genres_counted.index[:15],
                    color=genres_counted.values[:15],
                    color_continuous_scale='Agsunset')
genres_bar.show()

# %% [markdown]
# # Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
df_free_vs_paid.sort_values(by="App", ascending=False, inplace=True)
free_vs_paid_bar = px.bar(data_frame=df_free_vs_paid,
                          x='Category',
                          y='App',
                          color='Type',
                          barmode='group',
                          title='Free vs Paid Apps by Category'
                          )
free_vs_paid_bar.update_layout(xaxis_title="Number of Apps",
                      yaxis_title="Category of App",
                      yaxis=dict(type='log'),
                      xaxis=dict(tickangle=90))
free_vs_paid_bar.show()

# %% [markdown]
# # Lost Downloads for Paid Apps

# %%
giving_up_bar = px.box(data_frame=df_apps_clean,
                       y="Installs",
                       x="Type",
                       color="Type",
                       notched=True,
                       points='all',
                       title="How Many Downloads are Paid Apps Giving Up")
giving_up_bar.update_layout(yaxis=dict(type='log'), width=800,
                            height=600)
giving_up_bar.show()

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype('str').str.replace(",", '')
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)

df_apps_clean["Revenue_Estimate"] = df_apps_clean.Installs.mul(expensive_under_250.Price)
df_apps_clean.sort_values("Revenue_Estimate", ascending=False).head(10)


df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending', 
                         'tickangle': 90},
                  yaxis=dict(type='log'),
                  width=1200,
                  height=800)
 
 
box.show()
# Out:
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3132433747.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3132433747.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\gabso\AppData\Local\Temp\ipykernel_6244\3132433747.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
